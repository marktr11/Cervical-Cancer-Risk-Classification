# %%
import numpy as nb
import pandas as pd
import os
import sys
from sklearn.linear_model import LogisticRegression
from pathlib import Path
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.tree import plot_tree
from sklearn.svm import SVC
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
#from mlxtend.plotting import plot_decision_regions

from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize

# %%
base_dir = os.path.dirname(os.path.abspath(sys.argv[1]))
file_path = os.path.join(base_dir, "..\Data\sobar-72.csv")  
raw_path = Path(file_path)
corrected_path = raw_path.resolve()
print("Base directory:", base_dir)
print("File path:", file_path)
print("corrected path:", corrected_path)
df = pd.read_csv(corrected_path)
# Out:
# Base directory: C:\Users\ds311045\OneDrive - Université Côte d'Azur\2 éme année\projet Cancer\Risques-de-cancer-cervical\Code
# File path: C:\Users\ds311045\OneDrive - Université Côte d'Azur\2 éme année\projet Cancer\Risques-de-cancer-cervical\Code\..\Data\sobar-72.csv
# corrected path: C:\Users\ds311045\OneDrive - Université Côte d'Azur\2 éme année\projet Cancer\Risques-de-cancer-cervical\Data\sobar-72.csv

# %% [markdown]
# ### Données et variable cible

# %%
X = df.drop(["ca_cervix"], axis=1)
y=df["ca_cervix"]
X.shape
#y.shape
# Out:
# (72, 19)

# %% [markdown]
# ### Séparation des données entrainement et test

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,random_state=0)

# %% [markdown]
# # 1) Modéle arbre de décision

# %% [raw]
# L'arbre de décision est un excellent choix pour la classification du cancer cervical en raison de sa capacité à gérer des données complexes et à capturer des interactions entre les variables. Son interprétabilité permet aux médecins de visualiser facilement les critères influençant le diagnostic, tout en offrant de bonnes performances sur des jeux de données médicaux limités.

# %% [markdown]
# ### Création et entraînement du modèle

# %%
modele_tree = DecisionTreeClassifier(max_depth=5, random_state=42)
modele_tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=5, random_state=42)

# %% [markdown]
# ### Prédiction et évaluation

# %%
y_pred_tree = modele_tree.predict(X_test)
accuracy_tree = accuracy_score(y_test, y_pred_tree)
print(f"Précision du modèle : {accuracy_tree:.2f}")
print(classification_report(y_test, y_pred_tree))
# Out:
# Précision du modèle : 0.80
#               precision    recall  f1-score   support
#
#            0       0.92      0.86      0.89        14
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.80        15
#    macro avg       0.46      0.43      0.44        15
# weighted avg       0.86      0.80      0.83        15

# %% [markdown]
# ### Visualisation de l'arbre de décision

# %%
plt.figure(figsize=(12, 8))
plot_tree(modele_tree, feature_names=X.columns, class_names=["Pas de cancer", "Présence de cancer"], filled=True)
plt.show()

# %% [raw]
# Les nœuds représentent les décisions prises par l’arbre à chaque étape.
# Les valeurs affichées indiquent la condition de séparation (feature ≤ valeur).
# Les couleurs montrent la classe dominante dans chaque nœud.
#
# une feuille est bleu foncé, cela signifie que la majorité des données dans cette région appartiennent à la "0" donc "Par de cancer".
#
# Les proportions de chaque classe sont affichées dans les feuilles terminales.

# %% [markdown]
# # 2) Modéle Regression logistique

# %% [raw]
# La régression logistique est un choix idéal pour la classification du cancer cervical grâce à sa simplicité, son interprétabilité et sa robustesse sur de petits jeux de données. Elle permet d'identifier les facteurs de risque et d'offrir des prédictions transparentes, facilitant ainsi la prise de décision médicale.
#
# Contrairement à la régression linéaire qui prédit des valeurs continues, la régression logistique prédit des probabilités et applique une transformation sigmoïde pour obtenir une sortie entre 0 et 1
# Si la probabilité est > 0.5, on classe l’observation en 1 (Présence de cancer) Sinon, elle est classée en 0 (Pas de cancer)

# %% [markdown]
# $\huge
# p(y = 1 | x) = \frac{1}{1 + e^{-(\theta_0 + \theta_1 x_1 + \theta_2 x_2 + \dots + \theta_n x_n)}}$

# %% [markdown]
# ### Création et entraitement du modéle

# %%
modele_logistique = LogisticRegression(solver="saga",max_iter=10000)  # Augmenter les itérations
modele_logistique.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=10000, solver='saga')

# %% [markdown]
# ### Prédiction

# %%
y_pred_logistique = modele_logistique.predict(X_test)

# %% [markdown]
# ### Evaluation

# %%
# Score d'accuracy
print("Accuracy :", accuracy_score(y_test, y_pred_logistique))

# Matrice de confusion
print("Matrice de confusion :\n", confusion_matrix(y_test, y_pred_logistique))

# Rapport détaillé des performances (Précision, Rappel, F1-score)
print("Rapport de classification :\n", classification_report(y_test, y_pred_logistique))
# Out:
# Accuracy : 0.8666666666666667
# Matrice de confusion :
#  [[13  1]
#  [ 1  0]]
# Rapport de classification :
#                precision    recall  f1-score   support
#
#            0       0.93      0.93      0.93        14
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.87        15
#    macro avg       0.46      0.46      0.46        15
# weighted avg       0.87      0.87      0.87        15

# %% [markdown]
# ### Interpretation des coefficients du modéle

# %%
coef = pd.DataFrame({"Feature": X.columns, "Coefficient": modele_logistique.coef_[0]})
print(coef.sort_values(by="Coefficient", ascending=False))
# Un coefficient positif indique que la variable augmente la probabilité d'appartenir à la classe 1 "présence du cancer".
# Un coefficient négatif indique que la variable diminue cette probabilité
# Out:
#                        Feature  Coefficient
# 5         attitude_consistency     0.712169
# 1              behavior_eating     0.654646
# 15  socialSupport_instrumental     0.512546
# 0          behavior_sexualRisk     0.332018
# 12      motivation_willingness     0.109132
# 6         attitude_spontaneity     0.068348
# 14  socialSupport_appreciation     0.032305
# 13  socialSupport_emotionality     0.014675
# 2      behavior_personalHygine    -0.023301
# 9     perception_vulnerability    -0.070568
# 4         intention_commitment    -0.079098
# 11         motivation_strength    -0.190399
# 7       norm_significantPerson    -0.211534
# 8             norm_fulfillment    -0.229111
# 17       empowerment_abilities    -0.299881
# 16       empowerment_knowledge    -0.307163
# 3        intention_aggregation    -0.353857
# 18         empowerment_desires    -0.751030
# 10         perception_severity    -0.861104

# %% [markdown]
# # 3) Modèle SVM (Support Vector Machine)

# %% [raw]
# Le SVM est un bon choix pour la classification du cancer cervical grâce à sa capacité à gérer des données complexes et
# à bien fonctionner même sur des ensembles de données de petite taille. En trouvant une frontière optimale entre les classes, il offre une bonne précision, surtout lorsque les données ne sont pas linéairement séparables, tout en étant moins sensible aux outliers.

# %% [markdown]
# ### Intanciation et entrainement du modéle

# %%
modele_svm = SVC(kernel="linear", C=1.0,probability=True)
modele_svm.fit(X_train, y_train)
# Out:
# SVC(kernel='linear', probability=True)

# %% [markdown]
# ### Prédiction

# %%
y_pred_svm = modele_svm.predict(X_test)

# %% [markdown]
# ### Evaluation

# %%
print("Accuracy:", accuracy_score(y_test, y_pred_svm))
print("Matrice de confusion:\n", confusion_matrix(y_test, y_pred_svm))
print("Rapport de classification:\n", classification_report(y_test, y_pred_svm))
# Out:
# Accuracy: 0.9333333333333333
# Matrice de confusion:
#  [[14  0]
#  [ 1  0]]
# Rapport de classification:
#                precision    recall  f1-score   support
#
#            0       0.93      1.00      0.97        14
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.93        15
#    macro avg       0.47      0.50      0.48        15
# weighted avg       0.87      0.93      0.90        15
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### Visualisation de la frontiére de decission

# %%
#import matplotlib.pyplot as plt
#from mlxtend.plotting import plot_decision_regions
#plt.figure(figsize=(8, 6))
#plot_decision_regions(X_train.to_numpy(), y_train.to_numpy(), clf=modele_svm, legend=2)
#plt.title("Frontière de décision SVM")
#plt.show()

# %% [markdown]
# # 4) Modéle K NN

# %% [raw]
# Le choix de K-NN pour la classification du cancer cervical en raison de sa simplicité et de sa capacité à s'adapter aux données sans hypothèses strictes. Il fonctionne bien avec des jeux de données médicaux de taille modérée et peut capturer des relations complexes, mais il peut être sensible aux données déséquilibrées et nécessite un bon choix de k pour optimiser la précision.

# %% [markdown]
# ### Instanciation et entrainement

# %%
modele_knn = KNeighborsClassifier(n_neighbors=3)
modele_knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %% [markdown]
# ### Prédiction

# %%
y_pred_knn = modele_knn.predict(X_test)

# %% [markdown]
# ### Evaluation

# %%
accuracy = accuracy_score(y_test, y_pred_knn)
print(f"Accuracy: {accuracy * 100:.2f}%")
# Out:
# Accuracy: 93.33%

# %% [markdown]
# ### Optimisation du paramétre K

# %%
from sklearn.model_selection import cross_val_score

# Tester plusieurs valeurs de k
k_range = range(1, 11)
k_scores = []

for k in k_range:
    knn = KNeighborsClassifier(n_neighbors=k)
    scores = cross_val_score(knn, X, y, cv=5, scoring='accuracy')
    k_scores.append(scores.mean())

# Afficher la meilleure valeur de k
best_k = k_range[np.argmax(k_scores)]
print(f"Le meilleur k est {best_k} avec une précision de {max(k_scores) * 100:.2f}%")
# Out:
# Le meilleur k est 9 avec une précision de 87.62%

# %% [markdown]
# # Choix du meilleur modéle

# %%
models = [
    ("Arbre de decision", modele_tree),
    ("Logistic Regression", modele_logistique),
    ("Support Vector Machine", modele_svm),
    ("K-Nearest Neighbors", modele_knn)
]

# Créer la figure pour afficher les courbes ROC
plt.figure(figsize=(10, 8))

# Boucle pour calculer et tracer les courbes ROC pour chaque modèle
for name, model in models:
    # Prédictions de probabilité
    y_prob = model.predict_proba(X_test)[:, 1]  # Utilise la probabilité de la classe positive
    
    # Calcul des courbes ROC
    fpr, tpr, _ = roc_curve(y_test_bin, y_prob)
    
    # Calcul de l'aire sous la courbe (AUC)
    roc_auc = auc(fpr, tpr)
    
    # Tracer la courbe ROC
    plt.plot(fpr, tpr, label=f'{name} (AUC = {roc_auc:.2f})')

# Tracer la diagonale (AUC = 0.5, modèle aléatoire)
plt.plot([0, 1], [0, 1], color='navy', linestyle='--')

# Ajouter des labels et la légende
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Courbes ROC pour différents modèles')
plt.legend(loc='lower right')

# Afficher la courbe
plt.show()
plt.savefig('Courbes_ROC_pour_différents_modèles.pdf', dpi=300, bbox_inches='tight', transparent=True)
